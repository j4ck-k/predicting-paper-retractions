# %%
from pyalex import Works, Authors, Sources, Institutions, Concepts, Publishers, Funders
import pandas as pd
from collections import Counter

# %%
pager = Works().filter(
    primary_location={"source": {"id" : "s202381698"}},
    publication_year=">2018",
    is_retracted='true'
    ).paginate(per_page=200)

# %%
specified_columns = [
    'id',
    'title',
    'authorships',
    'publication_year',
    'countries_distinct_count',
    'institutions_distinct_count',
    'referenced_works_count',
    'is_retracted'
]

max_limit_pages = -1 # Set to -1 for all pages

output_df = pd.DataFrame(columns=specified_columns)
output_df['is_retracted'] = output_df['is_retracted'].astype(bool)

page_count = 0
for page in pager:
  print(f"Page: {page_count}")
  output_df = pd.concat([
    output_df,
    pd.DataFrame(
      page,
      columns=specified_columns
    )
  ])
  page_count += 1
  if page_count == max_limit_pages:
    break

print(len(output_df))
# Out:
# Page: 0
# Page: 1
# Page: 2
# 237

# %%
output_df
# Out:
#                                   id  \
# 0   https://openalex.org/W3134443160
# 1   https://openalex.org/W3014779806
# 2   https://openalex.org/W3209586559
# 3   https://openalex.org/W3024735271
# 4   https://openalex.org/W4213453867
# ..                               ...
# 32  https://openalex.org/W4292219993
# 33  https://openalex.org/W2916143521
# 34  https://openalex.org/W3130064135
# 35  https://openalex.org/W3196834656
# 36  https://openalex.org/W3203999704
#
#                                                 title  \
# 0   The anti-vaccination infodemic on social media...
# 1   ACC-deaminase producing plant growth promoting...
# 2   Application of local fully Convolutional Neura...
# 3   Terminal drought and heat stress alter physiol...
# 4   Effect of zinc nanoparticles seed priming and ...
# ..                                                ...
# 32  Medication regimen complexity and its associat...
# 33  Identifying developmental trajectories of worl...
# 34  Prevalence of rheumatic heart disease in a maj...
# 35  Analysis on frosting of heat exchanger and num...
# 36  Transcriptome profiling reveals new insights i...
#
#                                           authorships publication_year  \
# 0   [{'author_position': 'first', 'author': {'id':...             2021
# 1   [{'author_position': 'first', 'author': {'id':...             2020
# 2   [{'author_position': 'first', 'author': {'id':...             2021
# 3   [{'author_position': 'first', 'author': {'id':...             2020
# 4   [{'author_position': 'first', 'author': {'id':...             2022
# ..                                                ...              ...
# 32  [{'author_position': 'first', 'author': {'id':...             2022
# 33  [{'author_position': 'first', 'author': {'id':...             2019
# 34  [{'author_position': 'first', 'author': {'id':...             2021
# 35  [{'author_position': 'first', 'author': {'id':...             2021
# 36  [{'author_position': 'first', 'author': {'id':...             2021
#
#    countries_distinct_count institutions_distinct_count  \
# 0                         1                           1
# 1                         2                           2
# 2                         1                           3
# 3                         3                           4
# 4                         4                          10
# ..                      ...                         ...
# 32                        1                           2
# 33                        1                           1
# 34                        2                           3
# 35                        1                           1
# 36                        1                           1
#
#    referenced_works_count is_retracted
# 0                      44         True
# 1                      48         True
# 2                      16         True
# 3                      52         True
# 4                      46         True
# ..                    ...          ...
# 32                     34         True
# 33                     13         True
# 34                     25         True
# 35                     33         True
# 36                     49         True
#
# [237 rows x 8 columns]

# %%
output_df.iloc[0]['authorships'][0]
# Out:
# {'author_position': 'first',
#  'author': {'id': 'https://openalex.org/A5066021330',
#   'display_name': 'Federico Germani',
#   'orcid': 'https://orcid.org/0000-0002-5604-0437'},
#  'institutions': [{'id': 'https://openalex.org/I202697423',
#    'display_name': 'University of Zurich',
#    'ror': 'https://ror.org/02crff812',
#    'country_code': 'CH',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I202697423']}],
#  'countries': ['CH'],
#  'is_corresponding': True,
#  'raw_author_name': 'Federico Germani',
#  'raw_affiliation_string': 'Institute of Biomedical Ethics and History of Medicine, University of Zurich, Zürich, Switzerland',
#  'raw_affiliation_strings': ['Institute of Biomedical Ethics and History of Medicine, University of Zurich, Zürich, Switzerland']}

# %%
authors = list(output_df['authorships'].values)

# %%
ids = []

for author_dicts in authors:
    for author_dict in author_dicts:
        ids.append(author_dict['author']['id'])

# %%
unique_ids = list(set(ids))
count_ids = Counter(ids)

# %%
retracted_authors = pd.DataFrame(unique_ids, columns=['ID'])
retracted_authors
# Out:
#                                     ID
# 0     https://openalex.org/A5046119891
# 1     https://openalex.org/A5091317710
# 2     https://openalex.org/A5089407824
# 3     https://openalex.org/A5035213015
# 4     https://openalex.org/A5018416840
# ...                                ...
# 1345  https://openalex.org/A5074090595
# 1346  https://openalex.org/A5003651969
# 1347  https://openalex.org/A5048632692
# 1348  https://openalex.org/A5040205022
# 1349  https://openalex.org/A5015742130
#
# [1350 rows x 1 columns]

# %%
get_displayName = lambda x : Authors()[x]['display_name']
get_paperCounts = lambda x : count_ids[x]

# %%
retracted_authors['DisplayName'] = retracted_authors['ID'].apply(get_displayName)

# %%
retracted_authors['Retractions'] = retracted_authors['ID'].apply(get_paperCounts)

# %%
retracted_authors.sort_values(by='Retractions', ascending=False)
# Out:
#                                     ID                DisplayName  Retractions
# 1201  https://openalex.org/A5011637406      Mohammad Javed Ansari           19
# 672   https://openalex.org/A5068852002           Ali Tan Kee Zuan           18
# 75    https://openalex.org/A5002674897            Mubshar Hussain           12
# 964   https://openalex.org/A5063970370        Ahmed M. El-Shehawi           11
# 500   https://openalex.org/A5019980755              Subhan Danish            9
# ...                                ...                        ...          ...
# 1313  https://openalex.org/A5050770854  Katarzyna Kotwica-Mojzych            1
# 4     https://openalex.org/A5018416840             Muhammad Iqbal            1
# 1315  https://openalex.org/A5059438758             Muneeba Haider            1
# 1316  https://openalex.org/A5085306260                  Nida Baig            1
# 3     https://openalex.org/A5035213015          Moira M. Ferguson            1
#
# [1350 rows x 3 columns]

# %%
save = True

if save:
  output_df.to_csv('retracted-authors-plos1-2018.csv')
  print('Saved')
# Out:
# Saved

# %%
def anyRetractedAuthors(authors : list) -> bool:
    retracted = False

    for author_dict in authors:
        if author_dict['author']['id'] in list(retracted_authors['ID'].values):
            retracted = True
    
    return retracted

# %%
def countAuthorRetractions(authors : list) -> int:
    count = 0

    for author_dict in authors:
        if author_dict['author']['id'] in list(retracted_authors['ID'].values):
            row_index = retracted_authors.index.get_loc(retracted_authors[retracted_authors['ID'] == author_dict['author']['id']].index[0])
            count += retracted_authors.iloc[row_index]['Retractions']
    
    return count

# %%
def countRetractedAuthors(authors : list) -> int:
    count = 0

    for author_dict in authors:
        if author_dict['author']['id'] in list(retracted_authors['ID'].values):
            count += 1
    
    return count

# %%
pager = Works().filter(
    primary_location={"source": {"id" : "s202381698"}},
    publication_year=">2018"
    ).paginate(per_page=200)

# %%
specified_columns = [
    'id',
    'title',
    'authorships',
    'publication_year',
    'countries_distinct_count',
    'institutions_distinct_count',
    'referenced_works_count',
    'is_retracted'
]

max_limit_pages = 10 # Set to -1 for all pages

output_df = pd.DataFrame(columns=specified_columns)
output_df['is_retracted'] = output_df['is_retracted'].astype(bool)

page_count = 0
for page in pager:
  print(f"Page: {page_count}")
  output_df = pd.concat([
    output_df,
    pd.DataFrame(
      page,
      columns=specified_columns
    )
  ])
  page_count += 1
  if page_count == max_limit_pages:
    break

print(len(output_df))
# Out:
# Page: 0
# Page: 1
# Page: 2
# Page: 3
# Page: 4
# Page: 5
# Page: 6
# Page: 7
# Page: 8
# Page: 9
# 2000

# %%
output_df.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W3011720761
# 1  https://openalex.org/W3045484639
# 2  https://openalex.org/W3023639742
# 3  https://openalex.org/W2981679558
# 4  https://openalex.org/W3019119825
#
#                                                title  \
# 0  Mental health problems and social media exposu...
# 1  Students under lockdown: Comparisons of studen...
# 2  A simple method to assess and report thematic ...
# 3  Machine learning algorithm validation with a l...
# 4  Machine learning using intrinsic genomic signa...
#
#                                          authorships publication_year  \
# 0  [{'author_position': 'first', 'author': {'id':...             2020
# 1  [{'author_position': 'first', 'author': {'id':...             2020
# 2  [{'author_position': 'first', 'author': {'id':...             2020
# 3  [{'author_position': 'first', 'author': {'id':...             2019
# 4  [{'author_position': 'first', 'author': {'id':...             2020
#
#   countries_distinct_count institutions_distinct_count referenced_works_count  \
# 0                        1                           1                     13
# 1                        1                           1                     38
# 2                        1                           2                     23
# 3                        1                           1                     26
# 4                        1                           2                     65
#
#    is_retracted
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
output_df['HasRetractedAuthor'] = output_df['authorships'].apply(anyRetractedAuthors)
output_df['NumberOfRetractedAuthors'] = output_df['authorships'].apply(countRetractedAuthors)
output_df['NumberOfAuthorRetractions'] = output_df['authorships'].apply(countAuthorRetractions)

# %%
output_df[output_df['HasRetractedAuthor']==True]
# Out:
#                                    id  \
# 94   https://openalex.org/W3134443160
# 14   https://openalex.org/W3014779806
# 37   https://openalex.org/W3209586559
# 77   https://openalex.org/W2968918584
# 93   https://openalex.org/W3024735271
# 178  https://openalex.org/W3022140670
# 159  https://openalex.org/W4213453867
# 160  https://openalex.org/W4220747412
# 180  https://openalex.org/W4205681551
# 187  https://openalex.org/W4319825978
# 45   https://openalex.org/W2912755977
# 88   https://openalex.org/W3014245704
# 94   https://openalex.org/W3116470704
# 164  https://openalex.org/W3017241190
# 176  https://openalex.org/W3083012311
# 95   https://openalex.org/W4200081380
# 146  https://openalex.org/W2922416496
# 99   https://openalex.org/W2912457391
# 104  https://openalex.org/W2948596301
# 6    https://openalex.org/W2996619590
# 57   https://openalex.org/W3200406958
# 142  https://openalex.org/W4205536705
# 195  https://openalex.org/W3182584070
# 14   https://openalex.org/W3154251597
# 102  https://openalex.org/W3195047309
# 112  https://openalex.org/W3119939294
#
#                                                  title  \
# 94   The anti-vaccination infodemic on social media...
# 14   ACC-deaminase producing plant growth promoting...
# 37   Application of local fully Convolutional Neura...
# 77   Investigation of antioxidant, antibacterial, a...
# 93   Terminal drought and heat stress alter physiol...
# 178  Combined seed and foliar pre-treatments with e...
# 159  Effect of zinc nanoparticles seed priming and ...
# 160  Seed nano-priming with Zinc Oxide nanoparticle...
# 180  Combined application of zinc and iron-lysine a...
# 187  An adversarial collaboration protocol for test...
# 45   Fecal microbiota transplantation for treatment...
# 88   Opening the black box of artificial intelligen...
# 94   Designing of a next generation multiepitope ba...
# 164  Halotolerant rhizobacteria Pseudomonas pseudoa...
# 176  Characterization of salt-tolerant plant growth...
# 95   Exogenous salicylic acid-induced drought stres...
# 146  Combined use of Enterobacter sp. MN17 and zeol...
# 99   Ocimum metabolomics in response to abiotic str...
# 104  ZnO-NPs embedded biodegradable thiolated banda...
# 6    Watered-down biodiversity? A comparison of met...
# 57   Acceptance of COVID-19 vaccine in Pakistan amo...
# 142  Expanding or shrinking? range shifts in wild u...
# 195  Moringa leaf extract improves biochemical attr...
# 14   Sodium nitroprusside application improves morp...
# 102  Pheno4D: A spatio-temporal dataset of maize an...
# 112  A new analysis method for evaluating bacterial...
#
#                                            authorships publication_year  \
# 94   [{'author_position': 'first', 'author': {'id':...             2021
# 14   [{'author_position': 'first', 'author': {'id':...             2020
# 37   [{'author_position': 'first', 'author': {'id':...             2021
# 77   [{'author_position': 'first', 'author': {'id':...             2019
# 93   [{'author_position': 'first', 'author': {'id':...             2020
# 178  [{'author_position': 'first', 'author': {'id':...             2020
# 159  [{'author_position': 'first', 'author': {'id':...             2022
# 160  [{'author_position': 'first', 'author': {'id':...             2022
# 180  [{'author_position': 'first', 'author': {'id':...             2022
# 187  [{'author_position': 'first', 'author': {'id':...             2023
# 45   [{'author_position': 'first', 'author': {'id':...             2019
# 88   [{'author_position': 'first', 'author': {'id':...             2020
# 94   [{'author_position': 'first', 'author': {'id':...             2020
# 164  [{'author_position': 'first', 'author': {'id':...             2020
# 176  [{'author_position': 'first', 'author': {'id':...             2020
# 95   [{'author_position': 'first', 'author': {'id':...             2021
# 146  [{'author_position': 'first', 'author': {'id':...             2019
# 99   [{'author_position': 'first', 'author': {'id':...             2019
# 104  [{'author_position': 'first', 'author': {'id':...             2019
# 6    [{'author_position': 'first', 'author': {'id':...             2019
# 57   [{'author_position': 'first', 'author': {'id':...             2021
# 142  [{'author_position': 'first', 'author': {'id':...             2021
# 195  [{'author_position': 'first', 'author': {'id':...             2021
# 14   [{'author_position': 'first', 'author': {'id':...             2021
# 102  [{'author_position': 'first', 'author': {'id':...             2021
# 112  [{'author_position': 'first', 'author': {'id':...             2021
#
#     countries_distinct_count institutions_distinct_count  \
# 94                         1                           1
# 14                         2                           2
# 37                         1                           3
# 77                         1                           2
# 93                         3                           4
# 178                        2                           2
# 159                        4                          10
# 160                        3                           5
# 180                        4                           8
# 187                        8                          21
# 45                         1                           3
# 88                         1                           1
# 94                         2                           4
# 164                        1                           1
# 176                        2                           2
# 95                         6                          11
# 146                        2                           5
# 99                         1                           2
# 104                        2                           7
# 6                          1                           4
# 57                         1                           4
# 142                        3                           3
# 195                        3                           6
# 14                         3                           5
# 102                        1                           2
# 112                        1                           1
#
#     referenced_works_count  is_retracted  HasRetractedAuthor  \
# 94                      44          True                True
# 14                      48          True                True
# 37                      16          True                True
# 77                      62         False                True
# 93                      52          True                True
# 178                     58         False                True
# 159                     46          True                True
# 160                     47         False                True
# 180                     70          True                True
# 187                     60         False                True
# 45                      59         False                True
# 88                      33         False                True
# 94                      97         False                True
# 164                     61         False                True
# 176                     47         False                True
# 95                      37          True                True
# 146                     60         False                True
# 99                      96         False                True
# 104                     40         False                True
# 6                       52         False                True
# 57                      28         False                True
# 142                     67         False                True
# 195                     37          True                True
# 14                      54          True                True
# 102                     53         False                True
# 112                     33         False                True
#
#      NumberOfRetractedAuthors  NumberOfAuthorRetractions
# 94                          2                          2
# 14                          4                         23
# 37                          8                          8
# 77                          2                          2
# 93                          8                         35
# 178                         3                          4
# 159                        14                         29
# 160                        10                         27
# 180                        10                         25
# 187                         1                          1
# 45                          1                          1
# 88                          1                          1
# 94                          4                          6
# 164                         4                          5
# 176                         4                         21
# 95                         15                         31
# 146                         2                          2
# 99                          1                          1
# 104                         1                          1
# 6                           1                          1
# 57                          2                          2
# 142                         1                          2
# 195                        11                         46
# 14                         14                         20
# 102                         1                          1
# 112                         1                          1
